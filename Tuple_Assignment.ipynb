# %% [markdown]
# <a href="https://colab.research.google.com/github/unnatiwaghe-sudo/python-practice-codes/blob/main/Tuple_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t=tuple("Hekko")
print(t)
# Out:
# ('H', 'e', 'k', 'k', 'o')

# %%
l=['a','e','i','o','u']
t=tuple(l)
print(t)
# Out:
# ('a', 'e', 'i', 'o', 'u')

# %%
t=tuple(input("enter elements: "))
print(t)
# Out:
# enter elements: 123456
# ('1', '2', '3', '4', '5', '6')

# %%
t1=eval(input("Enter:"))

print(t)
# Out:
# Enter:123445
# ('1', '2', '3', '4', '5', '6')

# %%
#create empty tupple
t=(1)
print(type(t))
t=tuple()
print(t)
# Out:
# <class 'int'>
# ()

# %%
t=1,2,3
print(type(t))
t=tuple()
print(t)
# Out:
# <class 'tuple'>
# ()

# %%
t=(1,2,3,4)
print(t)
t=(1.2,1.2,1.4,"a")
print(t)
#nested tuple
t=(1,2,3,(44,55))
print("NESTED TUPPLE=>",t)
# Out:
# (1, 2, 3, 4)
# (1.2, 1.2, 1.4, 'a')
# NESTED TUPPLE=> (1, 2, 3, (44, 55))

# %%
t1=tuple(input("Enter Element:"))
print(t1)
# Out:
# Enter Element:unnati
# ('u', 'n', 'n', 'a', 't', 'i')

# %%
t=(99,88,77,66,55,44,33,22)
print(t[0:5])  #0 to 3
print(t[::-1])  #reverse
print(t[-1:-5:-1])  #22,33,44,55  start :end-1:step
# Out:
# (99, 88, 77, 66, 55)
# (22, 33, 44, 55, 66, 77, 88, 99)
# (22, 33, 44, 55)

# %%
l=[1,2,3]
print(tuple(l))
s="python"
print(tuple(s))
#conver dic to tuple
d={1:"a",2:"b",3:"c"}
print(tuple(d))  #by default key
print(tuple(d.values())) #here value take not keys
# Out:
# (1, 2, 3)
# ('p', 'y', 't', 'h', 'o', 'n')
# (1, 2, 3)
# ('a', 'b', 'c')

# %%
#packed and unpacked
t=1,2   #packed
print(t)
x,y=(1,2)  #unpacked
print(x,y)
# Out:
# (1, 2)
# 1 2

# %%
t=(11,22,33,4,55,66)
for i in range(len(t)):
    print(t[i],end=" ")
# Out:
# 11 22 33 4 55 66

# %%
tup=(1,2,3)
tup1=(4,5,6)
tup+tup2
t=tup+tup1
print(t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4004236880.py in <cell line: 0>()
#       1 tup=(1,2,3)
#       2 tup1=(4,5,6)
# ----> 3 tup+tup2
#       4 t=tup+tup1
#       5 print(t)
#
# NameError: name 'tup2' is not defined

# %%
tup=(1,2,3,4,5,6,7,8,9)
seq=tup[3:-3]
print(seq)
seq2=tup[3:30]
print(seq2)
seq3=tup[9:21]
print(seq3)
se=tup[1:6:2]
print(se)
s=tup[1::3]
print(s)
seq5=tup[-3::2]
print(seq5)
# Out:
# (4, 5, 6)
# (4, 5, 6, 7, 8, 9)
# ()
# (2, 4, 6)
# (2, 5, 8)
# (7, 9)

# %%
#tuple function
t=(11,22,33,44,99,55,66)
print(len(t))  #4
print(max(t))  #55
print(min(t))  #11
print(t.index(44))
print(t.count(44))
print(sum(t))
print(sorted(t))
print(sorted(t,reverse=True))
# Out:
# 7
# 99
# 11
# 3
# 1
# 330
# [11, 22, 33, 44, 55, 66, 99]
# [99, 66, 55, 44, 33, 22, 11]

# %%
tup=(10,"hello",3.14)
print(tup)
# Out:
# (10, 'hello', 3.14)

# %%
tup=(1,2,3,4,5)
seq=tup[2]
print(seq)
# Out:
# 3
